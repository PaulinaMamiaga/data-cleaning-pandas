# %% [markdown]
# ### Shark attaks

# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: et_xmlfile in /opt/anaconda3/lib/python3.13/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /opt/anaconda3/lib/python3.13/site-packages (2.0.2)

# %%
import pandas as pd

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (2.1.3)

# %%
import numpy as np

# %%
df = pd.read_excel ("GSAF5.xls")
df.head()
# Out:
#              Date    Year        Type     Country                  State  \
# 0    14th October  2025.0  Unprovoked    Columbia   Bolivar, del Isolate
# 1    11th October  2025.0  Unprovoked   Australia             Queensland
# 2     7th October  2025.0  Unprovoked   Australia        South Australia
# 3  29th September  2025.0  Unprovoked         USA         Off California
# 4  27th September  2025.0    Provoked  Costa Rica                    NaN
#
#                          Location               Activity                Name  \
# 0               Catagena Province   Swimming with sharks          Male child
# 1  Cook Esplanade Thursday Island       Fishing/swimming          Samuel Nai
# 2                 Kangaroo Island                Surfing        Lee Berryman
# 3                 Catalina Island               Swimming  Christopher Murray
# 4                   Cocos Islands  Diving-Tagging sharks  Dr. Mauricio Hoyos
#
#   Sex  Age  ...             Species   \
# 0   M   14  ...         Nurse shark
# 1   M   14  ...  Tiger or Bull shark
# 2   M  50+  ...       Bronze whaler?
# 3   M   54  ...   unknown 1.2m shark
# 4   M   48  ...       Tiger shark 4m
#
#                                           Source  pdf href formula href  \
# 0  Kevin McMurray Trackingsharks.com Andy Currie  NaN          NaN  NaN
# 1              Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 2              Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 3  Todd Smith: Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 4  Todd Smith: Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
#
#   Case Number Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0         NaN           NaN            NaN         NaN         NaN
# 1         NaN           NaN            NaN         NaN         NaN
# 2         NaN           NaN            NaN         NaN         NaN
# 3         NaN           NaN            NaN         NaN         NaN
# 4         NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#              Date  Year        Type             Country              State  \
# 7045  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 7046  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 7047    1900-1905   0.0  Unprovoked                 USA     North Carolina
# 7048    1883-1889   0.0  Unprovoked              PANAMA                NaN
# 7049    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 7045                          Roebuck Bay        Diving
# 7046                                  NaN  Pearl diving
# 7047                       Ocracoke Inlet      Swimming
# 7048                 Panama Bay 8ºN, 79ºW           NaN
# 7049  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex  Age  ... Species   \
# 7045                   male   M  NaN  ...      NaN
# 7046                  Ahmun   M  NaN  ...      NaN
# 7047  Coast Guard personnel   M  NaN  ...      NaN
# 7048        Jules Patterson   M  NaN  ...      NaN
# 7049                   male   M   15  ...      NaN
#
#                                      Source                             pdf  \
# 7045       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 7046  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 7047   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 7048                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 7049                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 7045  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7046  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7047  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7048  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7049  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 7045  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0005
# 7046  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0004
# 7047  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
# 7048  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0002
# 7049  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0001
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 7045       ND.0005            6.0         NaN         NaN
# 7046       ND.0004            5.0         NaN         NaN
# 7047       ND.0003            4.0         NaN         NaN
# 7048       ND.0002            3.0         NaN         NaN
# 7049       ND.0001            2.0         NaN         NaN
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (7050, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7050 non-null   object
#  1   Year            7048 non-null   float64
#  2   Type            7032 non-null   object
#  3   Country         7000 non-null   object
#  4   State           6564 non-null   object
#  5   Location        6483 non-null   object
#  6   Activity        6465 non-null   object
#  7   Name            6831 non-null   object
#  8   Sex             6471 non-null   object
#  9   Age             4056 non-null   object
#  10  Injury          7015 non-null   object
#  11  Fatal Y/N       6489 non-null   object
#  12  Time            3524 non-null   object
#  13  Species         3919 non-null   object
#  14  Source          7030 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6794 non-null   object
#  17  href            6796 non-null   object
#  18  Case Number     6798 non-null   object
#  19  Case Number.1   6797 non-null   object
#  20  original order  6799 non-null   float64
#  21  Unnamed: 21     1 non-null      object
#  22  Unnamed: 22     2 non-null      object
# dtypes: float64(2), object(21)
# memory usage: 1.2+ MB

# %%
df.columns.tolist() # I see extra columns that were probably hidden in the excel file
# Out:
# ['Date',
#  'Year',
#  'Type',
#  'Country',
#  'State',
#  'Location',
#  'Activity',
#  'Name',
#  'Sex',
#  'Age',
#  'Injury',
#  'Fatal Y/N',
#  'Time',
#  'Species ',
#  'Source',
#  'pdf',
#  'href formula',
#  'href',
#  'Case Number',
#  'Case Number.1',
#  'original order',
#  'Unnamed: 21',
#  'Unnamed: 22']

# %%
df = df.iloc[:, :-9] # removing last 9 columns
df
# Out:
#                 Date    Year        Type             Country  \
# 0       14th October  2025.0  Unprovoked            Columbia
# 1       11th October  2025.0  Unprovoked           Australia
# 2        7th October  2025.0  Unprovoked           Australia
# 3     29th September  2025.0  Unprovoked                 USA
# 4     27th September  2025.0    Provoked          Costa Rica
# ...              ...     ...         ...                 ...
# 7045     Before 1903     0.0  Unprovoked           AUSTRALIA
# 7046     Before 1903     0.0  Unprovoked           AUSTRALIA
# 7047       1900-1905     0.0  Unprovoked                 USA
# 7048       1883-1889     0.0  Unprovoked              PANAMA
# 7049       1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                       State                             Location  \
# 0      Bolivar, del Isolate                    Catagena Province
# 1                Queensland       Cook Esplanade Thursday Island
# 2           South Australia                      Kangaroo Island
# 3            Off California                      Catalina Island
# 4                       NaN                        Cocos Islands
# ...                     ...                                  ...
# 7045      Western Australia                          Roebuck Bay
# 7046      Western Australia                                  NaN
# 7047         North Carolina                       Ocracoke Inlet
# 7048                    NaN                 Panama Bay 8ºN, 79ºW
# 7049       Eastern Province  Below the English fort, Trincomalee
#
#                    Activity                   Name Sex  Age  \
# 0      Swimming with sharks             Male child   M   14
# 1          Fishing/swimming             Samuel Nai   M   14
# 2                   Surfing           Lee Berryman   M  50+
# 3                  Swimming     Christopher Murray   M   54
# 4     Diving-Tagging sharks     Dr. Mauricio Hoyos   M   48
# ...                     ...                    ...  ..  ...
# 7045                 Diving                   male   M  NaN
# 7046           Pearl diving                  Ahmun   M  NaN
# 7047               Swimming  Coast Guard personnel   M  NaN
# 7048                    NaN        Jules Patterson   M  NaN
# 7049               Swimming                   male   M   15
#
#                                                  Injury Fatal Y/N        Time  \
# 0                                    Severe hand injury         N  Not stated
# 1                           Serious abdonminal injuries         N    1823 hrs
# 2                                  Lacerations to calf          N     1330hrs
# 3                                   Leg and foot injury         N     0100hrs
# 4                                    Head face and arms         N  Not stated
# ...                                                 ...       ...         ...
# 7045                                              FATAL         Y         NaN
# 7046                                              FATAL         Y         NaN
# 7047                                              FATAL         Y         NaN
# 7048                                              FATAL         Y         NaN
# 7049  FATAL. "Shark bit him in half, carrying away t...         Y         NaN
#
#                  Species
# 0            Nurse shark
# 1     Tiger or Bull shark
# 2          Bronze whaler?
# 3      unknown 1.2m shark
# 4          Tiger shark 4m
# ...                   ...
# 7045                  NaN
# 7046                  NaN
# 7047                  NaN
# 7048                  NaN
# 7049                  NaN
#
# [7050 rows x 14 columns]

# %%
df.columns.tolist() # Now I have 14 columns that I need
# Out:
# ['Date',
#  'Year',
#  'Type',
#  'Country',
#  'State',
#  'Location',
#  'Activity',
#  'Name',
#  'Sex',
#  'Age',
#  'Injury',
#  'Fatal Y/N',
#  'Time',
#  'Species ']

# %%
df.nunique()
# Out:
# Date         6094
# Year          261
# Type           13
# Country       249
# State         939
# Location     4598
# Activity     1608
# Name         5774
# Sex            10
# Age           251
# Injury       4167
# Fatal Y/N      12
# Time          462
# Species      1729
# dtype: int64

# %%
df.select_dtypes
# Out:
# <bound method DataFrame.select_dtypes of                 Date    Year        Type             Country  \
# 0       14th October  2025.0  Unprovoked            Columbia
# 1       11th October  2025.0  Unprovoked           Australia
# 2        7th October  2025.0  Unprovoked           Australia
# 3     29th September  2025.0  Unprovoked                 USA
# 4     27th September  2025.0    Provoked          Costa Rica
# ...              ...     ...         ...                 ...
# 7045     Before 1903     0.0  Unprovoked           AUSTRALIA
# 7046     Before 1903     0.0  Unprovoked           AUSTRALIA
# 7047       1900-1905     0.0  Unprovoked                 USA
# 7048       1883-1889     0.0  Unprovoked              PANAMA
# 7049       1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                       State                             Location  \
# 0      Bolivar, del Isolate                    Catagena Province
# 1                Queensland       Cook Esplanade Thursday Island
# 2           South Australia                      Kangaroo Island
# 3            Off California                      Catalina Island
# 4                       NaN                        Cocos Islands
# ...                     ...                                  ...
# 7045      Western Australia                          Roebuck Bay
# 7046      Western Australia                                  NaN
# 7047         North Carolina                       Ocracoke Inlet
# 7048                    NaN                 Panama Bay 8ºN, 79ºW
# 7049       Eastern Province  Below the English fort, Trincomalee
#
#                    Activity                   Name Sex  Age  \
# 0      Swimming with sharks             Male child   M   14
# 1          Fishing/swimming             Samuel Nai   M   14
# 2                   Surfing           Lee Berryman   M  50+
# 3                  Swimming     Christopher Murray   M   54
# 4     Diving-Tagging sharks     Dr. Mauricio Hoyos   M   48
# ...                     ...                    ...  ..  ...
# 7045                 Diving                   male   M  NaN
# 7046           Pearl diving                  Ahmun   M  NaN
# 7047               Swimming  Coast Guard personnel   M  NaN
# 7048                    NaN        Jules Patterson   M  NaN
# 7049               Swimming                   male   M   15
#
#                                                  Injury Fatal Y/N        Time  \
# 0                                    Severe hand injury         N  Not stated
# 1                           Serious abdonminal injuries         N    1823 hrs
# 2                                  Lacerations to calf          N     1330hrs
# 3                                   Leg and foot injury         N     0100hrs
# 4                                    Head face and arms         N  Not stated
# ...                                                 ...       ...         ...
# 7045                                              FATAL         Y         NaN
# 7046                                              FATAL         Y         NaN
# 7047                                              FATAL         Y         NaN
# 7048                                              FATAL         Y         NaN
# 7049  FATAL. "Shark bit him in half, carrying away t...         Y         NaN
#
#                  Species
# 0            Nurse shark
# 1     Tiger or Bull shark
# 2          Bronze whaler?
# 3      unknown 1.2m shark
# 4          Tiger shark 4m
# ...                   ...
# 7045                  NaN
# 7046                  NaN
# 7047                  NaN
# 7048                  NaN
# 7049                  NaN
#
# [7050 rows x 14 columns]>

# %%
df.dtypes
# Out:
# Date          object
# Year         float64
# Type          object
# Country       object
# State         object
# Location      object
# Activity      object
# Name          object
# Sex           object
# Age           object
# Injury        object
# Fatal Y/N     object
# Time          object
# Species       object
# dtype: object

# %%
df[["Year"]].tail() # year has missing values
# Out:
#       Year
# 7045   0.0
# 7046   0.0
# 7047   0.0
# 7048   0.0
# 7049   0.0

# %%
df[["Date"]].sample(20) # date includes the year
# Out:
#                       Date
# 1703           27-Sep-2010
# 5735           06-Jan-1932
# 6235           26-Mar-1905
# 5877  Reported 29-Oct-1926
# 5717           30-Aug-1932
# 5668           27-Aug-1934
# 2457           29-Sep-2003
# 4867           05-Nov-1958
# 4325           10-Jan-1966
# 6517           16-Jan-1884
# 4139              Jan-1970
# 283            01-May-2022
# 5859           12-Oct-1927
# 952            04-Aug-2016
# 5363                  1945
# 5201           21-Jul-1950
# 876            10-Apr-2017
# 5328           14-Oct-1946
# 2687            02-Ap-2001
# 2501           23-Apr-2003

# %%
df["Temp_year"] = df["Date"].astype(str).str.extract(r'(\d{4})').astype(float) # adding new temporary column to extract 4 digits of year from the column Date
df["Temp_year"]
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 7045    1903.0
# 7046    1903.0
# 7047    1900.0
# 7048    1883.0
# 7049    1845.0
# Name: Temp_year, Length: 7050, dtype: float64

# %%
df[['Date', 'Year', 'Temp_year']].sample(20)
# Out:
#                       Date    Year  Temp_year
# 3226              Mar-1993  1993.0     1993.0
# 2839           19-Jun-1999  1999.0     1999.0
# 3481                  1988  1988.0     1988.0
# 2055           03-Sep-2007  2007.0     2007.0
# 2916              Apr-1998  1998.0     1998.0
# 6564                 1880?  1880.0     1880.0
# 6284  Reported 29-Jun-1901  1901.0     1901.0
# 3028           25-Apr-1996  1996.0     1996.0
# 4891           15-Jun-1958  1958.0     1958.0
# 4446              Jan-1964  1964.0     1964.0
# 2308           14-May-2005  2005.0     2005.0
# 1644           10-May-2011  2011.0     2011.0
# 2392           22-May-2004  2004.0     2004.0
# 6103  Reported 30-Nov-1912  1912.0     1912.0
# 1020           04-Mar-2016  2016.0     2016.0
# 4818           02-Jul-1959  1959.0     1959.0
# 5568  Reported 06-Nov-1937  1937.0     1937.0
# 2679           12-Apr-2001  2001.0     2001.0
# 6780           19-Jul-1847  1847.0     1847.0
# 6746          28-Sept-1853  1853.0     1853.0

# %%
df['Year'] = df['Year'].fillna(df['Temp_year']) # Fill in the NaN in the Year column with the Temp year
df[['Date', 'Year', 'Temp_year']].sample(20)
# Out:
#              Date    Year  Temp_year
# 3477  21-Jan-1988  1988.0     1988.0
# 939   07-Sep-2016  2016.0     2016.0
# 3039  04-Feb-1996  1996.0     1996.0
# 5431  13-Nov-1942  1942.0     1942.0
# 6056  10-Nov-1915  1915.0     1915.0
# 531   24-Dec-2019  2019.0     2019.0
# 3781  17-Oct-1980  1980.0     1980.0
# 558   28-Sep-2019  2019.0     2019.0
# 4443  04-Jan-1964  1964.0     1964.0
# 4911         1958  1958.0     1958.0
# 4213     Mar-1968  1968.0     1968.0
# 2647  04-Aug-2001  2001.0     2001.0
# 4253  29-Jul-1967  1967.0     1967.0
# 4654  12-Feb-1961  1961.0     1961.0
# 5338  16-Feb-1946  1946.0     1946.0
# 4194  11-Aug-1968  1968.0     1968.0
# 560   24-Sep-2019  2019.0     2019.0
# 6074  13-Jun-1914  1914.0     1914.0
# 4960  07-Oct-1956  1956.0     1956.0
# 1960  28-Jun-2008  2008.0     2008.0

# %%
df_50 = df[~((df['Year'] < 1976) & (df['Temp_year'] < 1976))]
df_50[["Year", "Temp_year"]]
# Out:
#         Year  Temp_year
# 0     2025.0        NaN
# 1     2025.0        NaN
# 2     2025.0        NaN
# 3     2025.0        NaN
# 4     2025.0        NaN
# ...      ...        ...
# 7020     0.0        NaN
# 7023     0.0        NaN
# 7027     0.0        NaN
# 7028     0.0        NaN
# 7029     0.0        NaN
#
# [3973 rows x 2 columns]

# %%
df_50['Match_check'] = df_50['Year'] == df_50['Temp_year']
df_50['Match_check']
# Out:
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/2696524239.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7020    False
# 7023    False
# 7027    False
# 7028    False
# 7029    False
# Name: Match_check, Length: 3973, dtype: bool

# %%
print(df_50['Match_check'].value_counts())
# Out:
# Match_check
# True     3881
# False      92
# Name: count, dtype: int64

# %%
df_50_false = df_50[df_50['Match_check'] == False] 
df_50_false [["Year", "Temp_year"]]
# Out:
#         Year  Temp_year
# 0     2025.0        NaN
# 1     2025.0        NaN
# 2     2025.0        NaN
# 3     2025.0        NaN
# 4     2025.0        NaN
# ...      ...        ...
# 7020     0.0        NaN
# 7023     0.0        NaN
# 7027     0.0        NaN
# 7028     0.0        NaN
# 7029     0.0        NaN
#
# [92 rows x 2 columns]

# %%
df_50['Year'] = pd.to_numeric(df_50['Year'], errors='raise')   # turning the columns into numeric value to compare
df_50['Temp_year'] = pd.to_numeric(df_50['Temp_year'], errors='raise')
# Out:
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/3594179196.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/3594179196.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_50 = df_50[~(((df_50['Year'].isna()) | (df_50['Year'] == 0.0)) &
                 ((df_50['Temp_year'].isna()) | (df_50['Temp_year'] == 0.0)))]   # removing all rows that do not have any year information
df_50
# Out:
#                           Date    Year        Type           Country  \
# 0                 14th October  2025.0  Unprovoked          Columbia
# 1                 11th October  2025.0  Unprovoked         Australia
# 2                  7th October  2025.0  Unprovoked         Australia
# 3               29th September  2025.0  Unprovoked               USA
# 4               27th September  2025.0    Provoked        Costa Rica
# ...                        ...     ...         ...               ...
# 6969  No date, Before Mar-1995     0.0  Unprovoked  FRENCH POLYNESIA
# 6970               Before 1996     0.0  Unprovoked             SUDAN
# 6971  No date, Before Aug-1989     0.0  Unprovoked           VANUATU
# 6972  No date, Before Aug-1987     0.0    Provoked           VANUATU
# 6973      No date, Before 1987     0.0  Unprovoked              IRAN
#
#                       State                        Location  \
# 0      Bolivar, del Isolate               Catagena Province
# 1                Queensland  Cook Esplanade Thursday Island
# 2           South Australia                 Kangaroo Island
# 3            Off California                 Catalina Island
# 4                       NaN                   Cocos Islands
# ...                     ...                             ...
# 6969               Tuamotus                        Rangiroa
# 6970          Red Sea State                     Sha'ab Rumi
# 6971       Malampa Province                        Malakula
# 6972       Malampa Province                 Hokai, Malakula
# 6973     Khuzestan Province       Ahvaz, on the Karun River
#
#                                  Activity                Name Sex  Age  \
# 0                    Swimming with sharks          Male child   M   14
# 1                        Fishing/swimming          Samuel Nai   M   14
# 2                                 Surfing        Lee Berryman   M  50+
# 3                                Swimming  Christopher Murray   M   54
# 4                   Diving-Tagging sharks  Dr. Mauricio Hoyos   M   48
# ...                                   ...                 ...  ..  ...
# 6969                              Fishing                male   M  NaN
# 6970                               Diving      Erik Bjurstrom   M  NaN
# 6971                                  NaN              female   F  NaN
# 6972  Attempting to drive shark from area             a chief   M  NaN
# 6973                                  NaN     Mr. Jabar-Kaaby   M  NaN
#
#                                                  Injury Fatal Y/N        Time  \
# 0                                    Severe hand injury         N  Not stated
# 1                           Serious abdonminal injuries         N    1823 hrs
# 2                                  Lacerations to calf          N     1330hrs
# 3                                   Leg and foot injury         N     0100hrs
# 4                                    Head face and arms         N  Not stated
# ...                                                 ...       ...         ...
# 6969  Speared a shark, fell overboard and another sh...         N         NaN
# 6970                               No injury, BC ripped         N         NaN
# 6971                                              FATAL         Y         NaN
# 6972  Speared shark broke outrigger of canoe throwin...         N         NaN
# 6973                                       Foot severed         N         NaN
#
#                       Species   Temp_year  Match_check
# 0                 Nurse shark         NaN        False
# 1          Tiger or Bull shark        NaN        False
# 2               Bronze whaler?        NaN        False
# 3           unknown 1.2m shark        NaN        False
# 4               Tiger shark 4m        NaN        False
# ...                        ...        ...          ...
# 6969                       NaN     1995.0        False
# 6970           Silvertip shark     1996.0        False
# 6971                       NaN     1989.0        False
# 6972  A large hammerhead shark     1987.0        False
# 6973                Bull shark     1987.0        False
#
# [3960 rows x 16 columns]

# %%
df_50['Year'] = np.where(                                   # replacing missing value in Year with extracted value in Temp_year
    ((df_50['Year'].isna()) | (df_50['Year'] == 0.0)) &
    (df_50['Temp_year'].between(1000, 9999)),
    df_50['Temp_year'],
    df_50['Year']
)


df_50[["Year", "Temp_year"]]
# Out:
#         Year  Temp_year
# 0     2025.0        NaN
# 1     2025.0        NaN
# 2     2025.0        NaN
# 3     2025.0        NaN
# 4     2025.0        NaN
# ...      ...        ...
# 6969  1995.0     1995.0
# 6970  1996.0     1996.0
# 6971  1989.0     1989.0
# 6972  1987.0     1987.0
# 6973  1987.0     1987.0
#
# [3960 rows x 2 columns]

# %%
df_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3960 entries, 0 to 6973
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         3960 non-null   object
#  1   Year         3960 non-null   float64
#  2   Type         3945 non-null   object
#  3   Country      3954 non-null   object
#  4   State        3790 non-null   object
#  5   Location     3780 non-null   object
#  6   Activity     3740 non-null   object
#  7   Name         3888 non-null   object
#  8   Sex          3731 non-null   object
#  9   Age          2873 non-null   object
#  10  Injury       3947 non-null   object
#  11  Fatal Y/N    3690 non-null   object
#  12  Time         2624 non-null   object
#  13  Species      2567 non-null   object
#  14  Temp_year    3925 non-null   float64
#  15  Match_check  3960 non-null   bool
# dtypes: bool(1), float64(2), object(13)
# memory usage: 498.9+ KB

# %%
invalid_count = (~df_50['Year'].between(1000, 9999)).sum() # checking how many values are not 4 digits 
print("Number of invalid years:", invalid_count)
# Out:
# Number of invalid years: 2

# %%
df_50.loc[~df_50['Year'].between(1000, 9999), ['Date', 'Year', 'Temp_year']]
# Out:
#                Date  Year  Temp_year
# 6919   Ca. 77  A.D.  77.0        NaN
# 6920     Ca. 5 A.D.   5.0        NaN

# %%
df_50['Match_check'] = df_50['Year'] == df_50['Temp_year']
df_50['Match_check']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6969     True
# 6970     True
# 6971     True
# 6972     True
# 6973     True
# Name: Match_check, Length: 3960, dtype: bool

# %%
print(df_50['Match_check'].value_counts())
# Out:
# Match_check
# True     3906
# False      54
# Name: count, dtype: int64

# %%
df_50_false = df_50[df_50['Match_check'] == False]
df_50_false.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, 0 to 6920
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         54 non-null     object
#  1   Year         54 non-null     float64
#  2   Type         54 non-null     object
#  3   Country      53 non-null     object
#  4   State        49 non-null     object
#  5   Location     50 non-null     object
#  6   Activity     50 non-null     object
#  7   Name         54 non-null     object
#  8   Sex          53 non-null     object
#  9   Age          40 non-null     object
#  10  Injury       54 non-null     object
#  11  Fatal Y/N    49 non-null     object
#  12  Time         41 non-null     object
#  13  Species      43 non-null     object
#  14  Temp_year    19 non-null     float64
#  15  Match_check  54 non-null     bool
# dtypes: bool(1), float64(2), object(13)
# memory usage: 6.8+ KB

# %%
df_50[df_50['Temp_year'].isna()][['Date', 'Year', 'Temp_year']]
# Out:
#                       Date    Year  Temp_year
# 0             14th October  2025.0        NaN
# 1             11th October  2025.0        NaN
# 2              7th October  2025.0        NaN
# 3           29th September  2025.0        NaN
# 4           27th September  2025.0        NaN
# 5            6th September  2025.0        NaN
# 6            1st September  2025.0        NaN
# 7              30th August  2025.0        NaN
# 8              18th August  2025.0        NaN
# 9              17th August  2025.0        NaN
# 10             16th August  2025.0        NaN
# 11              7th August  2025.0        NaN
# 12              1st August  2025.0        NaN
# 13               28th July  2025.0        NaN
# 14               25th July  2025.0        NaN
# 15               22nd July  2025.0        NaN
# 16               20th July  2025.0        NaN
# 17               19th July  2025.0        NaN
# 18               18th July  2025.0        NaN
# 19               15th July  2025.0        NaN
# 20               6th July   2025.0        NaN
# 21                6th July  2025.0        NaN
# 22                4th July  2025.0        NaN
# 23               29th June  2025.0        NaN
# 24               25th June  2025.0        NaN
# 25               22nd June  2025.0        NaN
# 26               17th June  2025.0        NaN
# 28                31st May  2025.0        NaN
# 41               27-Feb-25  2025.0        NaN
# 485             10-Jul-202  2020.0        NaN
# 5379            22-Jul-144  1944.0        NaN
# 5537         Woirld War II  1939.0        NaN
# 5573  Reported 26-Sep-t937  1937.0        NaN
# 6919          Ca. 77  A.D.    77.0        NaN
# 6920            Ca. 5 A.D.     5.0        NaN

# %%
df_50_diff = df_50[((df_50['Temp_year'].notna()) & (df_50['Temp_year'] != df_50['Year'])) | (~df_50['Year'].between(1975, 2025))]

df_50_diff[['Date', 'Year', 'Temp_year']].head(20)                      # these are the years that don't match with Year - since its only 19 out of almost 4000 rows, we can remove this data
# Out:
#                       Date    Year  Temp_year
# 80     2024-07-04 00:00:00  2026.0     2024.0
# 81     2024-07-04 00:00:00  2025.0     2024.0
# 517            01-Feb-2010  2020.0     2010.0
# 551            25-Oct-2019  2018.0     2019.0
# 609            09-May-2018  2019.0     2018.0
# 629            18-Feb-2018  2019.0     2018.0
# 716               Jun-1018  2018.0     1018.0
# 1394           14-May-2014  2013.0     2014.0
# 1521              Apr-2013  2012.0     2013.0
# 1624           26-Jun-2008  2011.0     2008.0
# 1659  Reported 10-Mar-2010  2011.0     2010.0
# 1905           06-Dec-2006  2008.0     2006.0
# 2033         November 2011  2007.0     2011.0
# 3397           27-Jul-1989  1969.0     1989.0
# 3685           23-Oct-1962  1982.0     1962.0
# 4329        Summer of 1996  1966.0     1996.0
# 4810                 21764  1959.0     2176.0
# 5060                 19955  1954.0     1995.0
# 5379            22-Jul-144  1944.0        NaN
# 5537         Woirld War II  1939.0        NaN

# %%
df_50_last_years = df_50.drop(
    columns=["Temp_year", "Match_check", "Time"]).drop(index=df_50_diff.index.tolist() + [6919, 6920])
df_50_last_years
# Out:
#                           Date    Year        Type           Country  \
# 0                 14th October  2025.0  Unprovoked          Columbia
# 1                 11th October  2025.0  Unprovoked         Australia
# 2                  7th October  2025.0  Unprovoked         Australia
# 3               29th September  2025.0  Unprovoked               USA
# 4               27th September  2025.0    Provoked        Costa Rica
# ...                        ...     ...         ...               ...
# 6969  No date, Before Mar-1995  1995.0  Unprovoked  FRENCH POLYNESIA
# 6970               Before 1996  1996.0  Unprovoked             SUDAN
# 6971  No date, Before Aug-1989  1989.0  Unprovoked           VANUATU
# 6972  No date, Before Aug-1987  1987.0    Provoked           VANUATU
# 6973      No date, Before 1987  1987.0  Unprovoked              IRAN
#
#                       State                        Location  \
# 0      Bolivar, del Isolate               Catagena Province
# 1                Queensland  Cook Esplanade Thursday Island
# 2           South Australia                 Kangaroo Island
# 3            Off California                 Catalina Island
# 4                       NaN                   Cocos Islands
# ...                     ...                             ...
# 6969               Tuamotus                        Rangiroa
# 6970          Red Sea State                     Sha'ab Rumi
# 6971       Malampa Province                        Malakula
# 6972       Malampa Province                 Hokai, Malakula
# 6973     Khuzestan Province       Ahvaz, on the Karun River
#
#                                  Activity                Name Sex  Age  \
# 0                    Swimming with sharks          Male child   M   14
# 1                        Fishing/swimming          Samuel Nai   M   14
# 2                                 Surfing        Lee Berryman   M  50+
# 3                                Swimming  Christopher Murray   M   54
# 4                   Diving-Tagging sharks  Dr. Mauricio Hoyos   M   48
# ...                                   ...                 ...  ..  ...
# 6969                              Fishing                male   M  NaN
# 6970                               Diving      Erik Bjurstrom   M  NaN
# 6971                                  NaN              female   F  NaN
# 6972  Attempting to drive shark from area             a chief   M  NaN
# 6973                                  NaN     Mr. Jabar-Kaaby   M  NaN
#
#                                                  Injury Fatal Y/N  \
# 0                                    Severe hand injury         N
# 1                           Serious abdonminal injuries         N
# 2                                  Lacerations to calf          N
# 3                                   Leg and foot injury         N
# 4                                    Head face and arms         N
# ...                                                 ...       ...
# 6969  Speared a shark, fell overboard and another sh...         N
# 6970                               No injury, BC ripped         N
# 6971                                              FATAL         Y
# 6972  Speared shark broke outrigger of canoe throwin...         N
# 6973                                       Foot severed         N
#
#                       Species
# 0                 Nurse shark
# 1          Tiger or Bull shark
# 2               Bronze whaler?
# 3           unknown 1.2m shark
# 4               Tiger shark 4m
# ...                        ...
# 6969                       NaN
# 6970           Silvertip shark
# 6971                       NaN
# 6972  A large hammerhead shark
# 6973                Bull shark
#
# [3935 rows x 13 columns]

# %%
df_50_last_years = df_50_last_years.sort_values(by='Year', ascending=False)
df_50_last_years
# Out:
#                      Date    Year        Type       Country  \
# 0            14th October  2025.0  Unprovoked      Columbia
# 28               31st May  2025.0  Unprovoked           USA
# 30    2025-05-26 00:00:00  2025.0  Unprovoked       Vanuatu
# 31    2025-05-15 00:00:00  2025.0  Unprovoked     Australia
# 32    2025-05-08 00:00:00  2025.0  Unprovoked       Jamaica
# ...                   ...     ...         ...           ...
# 3913          02-May-1976  1976.0  Watercraft  SOUTH AFRICA
# 3914          28-Apr-1976  1976.0     Invalid           USA
# 3915          12-Mar-1976  1976.0  Unprovoked           USA
# 3916          12-Mar-1976  1976.0  Watercraft  SOUTH AFRICA
# 3892          23-Nov-1976  1976.0     Invalid  SOUTH AFRICA
#
#                       State                          Location  \
# 0      Bolivar, del Isolate                 Catagena Province
# 28               California               Montara State Beach
# 30              South Santo              Espiitu Santo Island
# 31          South Australia                    Port Noarlunga
# 32              Montego Bay                   Rose Hall beach
# ...                     ...                               ...
# 3913  Western Cape Province              40 km off Cape Point
# 3914                  Texas                  Galveston Island
# 3915                Florida  New Smyrna Beach, Volusia County
# 3916  Western Cape Province                     Robberg Point
# 3892          KwaZulu-Natal                      Warner Beach
#
#                                       Activity  \
# 0                         Swimming with sharks
# 28                                     Surfing
# 30                                    Swimming
# 31                                    Swimming
# 32                                    Paddling
# ...                                        ...
# 3913  Competing in a light tackle game fishing
# 3914                                       NaN
# 3915                                  Standing
# 3916                                   Fishing
# 3892                                  Swimming
#
#                                                    Name  Sex       Age  \
# 0                                            Male child    M        14
# 28                                          Jens Heller    M        42
# 30                                                Tumas    M        14
# 31                                       Richard Vinall    M        66
# 32                                         Rachel Smith    F        26
# ...                                                 ...  ...       ...
# 3913  6 m skiboat, occupants: Terry McManus, Dan Cla...  NaN       NaN
# 3914                                            Unknown  NaN       NaN
# 3915                                        Glen Wright    M  21 or 26
# 3916               boat, occupants: Jacob Kruger & crew  NaN       NaN
# 3892                                      Jimmy Jackson    M        17
#
#                                                  Injury Fatal Y/N  \
# 0                                    Severe hand injury         N
# 28                                           No injury          N
# 30    Multiple injuries to body one hand and leg bit...         Y
# 31                                      Injury to thigh         N
# 32               minor injuries to fingers of left hand         N
# ...                                                 ...       ...
# 3913   Shark following hooked fish, rammed & holed boat         N
# 3914  Possible drowning victim, remains retrieved fr...       NaN
# 3915                            Lacerations to left leg         N
# 3916   No injury to occupants, shark buckled prop shaft         N
# 3892                                 Laceration to foot       NaN
#
#                                                Species
# 0                                          Nurse shark
# 28                                          Great White
# 30                                           Not stated
# 31                                           Not stated
# 32                            Small shark 1m (3ft) long
# ...                                                 ...
# 3913                        Mako shark, 180-kg [397-lb]
# 3914  Shark involvement prior to death was not confi...
# 3915                                                NaN
# 3916                                        Whale shark
# 3892                              Questionable incident
#
# [3935 rows x 13 columns]

# %% [markdown]
# # From this point filtered data for last 50 years

# %%
df_50_last_years.nunique() # next we need to clean Country, Sex, Age, Fatal
                            # how to clean and sort age and activity??
# Out:
# Date         3342
# Year           50
# Type           12
# Country       154
# State         488
# Location     2674
# Activity      624
# Name         3285
# Sex             7
# Age           205
# Injury       2416
# Fatal Y/N       8
# Species      1187
# dtype: int64

# %% [markdown]
# ## Clean Country

# %%
df_50_last_years['Country'].unique()
# Out:
# array(['Columbia', 'USA', 'Vanuatu', 'Australia', 'Jamaica', 'Israel',
#        'Mexico', 'Maldives', 'Philippines', 'Bahamas', 'Turks and Caicos',
#        'Mozambique', 'New Caledonia', 'French Polynesia', 'Costa Rica',
#        'Puerto Rico', 'Spain', 'Canary Islands', 'South Africa',
#        'Maldive Islands', 'Tobago', 'AUSTRALIA', 'INDIA', 'TRINIDAD',
#        'BAHAMAS', 'SOUTH AFRICA', 'Thailand', 'Honduras', 'Egypt',
#        'New Zealand', 'Hawaii', 'Indonesia', 'Belize', 'Morocco', 'CUBA',
#        'TURKS and CaICOS', 'NEW CALEDONIA', 'FRENCH POLYNESIA', 'EGYPT',
#        'BRAZIL', 'MeXICO', 'FIJI', 'ARGENTINA', 'SEYCHELLES', 'MEXICO',
#        'ECUADOR', 'BELIZE', 'NEW ZEALAND', 'SPAIN', 'COLOMBIA', 'SAMOA',
#        'PORTUGAL', 'Coral Sea', 'PHILIPPINES', 'THAILAND', 'MALDIVES',
#        'JAMAICA', 'COLUMBIA', 'COSTA RICA', 'INDONESIA', 'JAPAN',
#        'ENGLAND', 'ST KITTS / NEVIS', 'JORDAN',
#        'British Overseas Territory', 'CANADA', 'ST MARTIN',
#        'REUNION ISLAND', 'CHINA', 'ISRAEL', 'PAPUA NEW GUINEA', 'IRELAND',
#        'ITALY', 'REUNION', 'ST HELENA, British overseas territory',
#        'UNITED ARAB EMIRATES', 'UNITED KINGDOM', 'COMOROS', 'MAURITIUS',
#        'LIBYA', nan, 'MALAYSIA', 'SOLOMON ISLANDS', 'DOMINICAN REPUBLIC',
#        'CAPE VERDE', 'KENYA', 'CAYMAN ISLANDS', 'Fiji', 'PUERTO RICO',
#        'ATLANTIC OCEAN', 'MOZAMBIQUE', 'ARUBA', 'FRANCE', 'ST. MARTIN',
#        'TRINIDAD & TOBAGO', 'GREECE', 'PALESTINIAN TERRITORIES', 'TAIWAN',
#        'DIEGO GARCIA', 'GUAM', 'KIRIBATI', 'CHILE', 'SAUDI ARABIA',
#        'NIGERIA', 'CROATIA', 'TONGA', 'SCOTLAND',
#        'UNITED ARAB EMIRATES (UAE)', 'TURKS & CAICOS', 'SUDAN', 'ANTIGUA',
#        'RUSSIA', 'MADAGASCAR', 'VIETNAM', 'AZORES', 'MALTA',
#        'SOUTH KOREA', 'PANAMA', 'SOMALIA', 'NEVIS', 'SENEGAL', 'YEMEN',
#        'NORWAY', 'BRITISH VIRGIN ISLANDS', 'Sierra Leone', 'GULF OF ADEN',
#        'MEXICO ', 'VANUATU', 'VENEZUELA', 'HONDURAS', 'GRAND CAYMAN',
#        'ST. MAARTIN', 'LIBERIA', 'Seychelles', ' TONGA', 'URUGUAY',
#        'SRI LANKA', 'MICRONESIA', 'CARIBBEAN SEA', 'TANZANIA', 'OKINAWA',
#        'MARSHALL ISLANDS', 'KOREA', 'EGYPT / ISRAEL', 'HONG KONG',
#        'NORTHERN ARABIAN SEA', 'ANGOLA', 'EL SALVADOR', 'MONTENEGRO',
#        'IRAN', 'TUNISIA', 'BERMUDA', 'NAMIBIA', 'NORTH ATLANTIC OCEAN',
#        'SOUTH CHINA SEA'], dtype=object)

# %%
df_50_last_years['Country'] = df_50_last_years['Country'].str.strip().str.title()

# %%
df_50_last_years['Country'].dropna().sort_values().unique()
# Out:
# array(['Angola', 'Antigua', 'Argentina', 'Aruba', 'Atlantic Ocean',
#        'Australia', 'Azores', 'Bahamas', 'Belize', 'Bermuda', 'Brazil',
#        'British Overseas Territory', 'British Virgin Islands', 'Canada',
#        'Canary Islands', 'Cape Verde', 'Caribbean Sea', 'Cayman Islands',
#        'Chile', 'China', 'Colombia', 'Columbia', 'Comoros', 'Coral Sea',
#        'Costa Rica', 'Croatia', 'Cuba', 'Diego Garcia',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'Egypt / Israel',
#        'El Salvador', 'England', 'Fiji', 'France', 'French Polynesia',
#        'Grand Cayman', 'Greece', 'Guam', 'Gulf Of Aden', 'Hawaii',
#        'Honduras', 'Hong Kong', 'India', 'Indonesia', 'Iran', 'Ireland',
#        'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kenya',
#        'Kiribati', 'Korea', 'Liberia', 'Libya', 'Madagascar', 'Malaysia',
#        'Maldive Islands', 'Maldives', 'Malta', 'Marshall Islands',
#        'Mauritius', 'Mexico', 'Micronesia', 'Montenegro', 'Morocco',
#        'Mozambique', 'Namibia', 'Nevis', 'New Caledonia', 'New Zealand',
#        'Nigeria', 'North Atlantic Ocean', 'Northern Arabian Sea',
#        'Norway', 'Okinawa', 'Palestinian Territories', 'Panama',
#        'Papua New Guinea', 'Philippines', 'Portugal', 'Puerto Rico',
#        'Reunion', 'Reunion Island', 'Russia', 'Samoa', 'Saudi Arabia',
#        'Scotland', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South China Sea',
#        'South Korea', 'Spain', 'Sri Lanka',
#        'St Helena, British Overseas Territory', 'St Kitts / Nevis',
#        'St Martin', 'St. Maartin', 'St. Martin', 'Sudan', 'Taiwan',
#        'Tanzania', 'Thailand', 'Tobago', 'Tonga', 'Trinidad',
#        'Trinidad & Tobago', 'Tunisia', 'Turks & Caicos',
#        'Turks And Caicos', 'United Arab Emirates',
#        'United Arab Emirates (Uae)', 'United Kingdom', 'Uruguay', 'Usa',
#        'Vanuatu', 'Venezuela', 'Vietnam', 'Yemen'], dtype=object)

# %%
df_50_last_years.head()
# Out:
#                    Date    Year        Type    Country                  State  \
# 0          14th October  2025.0  Unprovoked   Columbia   Bolivar, del Isolate
# 28             31st May  2025.0  Unprovoked        Usa             California
# 30  2025-05-26 00:00:00  2025.0  Unprovoked    Vanuatu            South Santo
# 31  2025-05-15 00:00:00  2025.0  Unprovoked  Australia        South Australia
# 32  2025-05-08 00:00:00  2025.0  Unprovoked    Jamaica            Montego Bay
#
#                 Location              Activity            Name Sex Age  \
# 0      Catagena Province  Swimming with sharks      Male child   M  14
# 28   Montara State Beach               Surfing     Jens Heller   M  42
# 30  Espiitu Santo Island              Swimming           Tumas   M  14
# 31        Port Noarlunga              Swimming  Richard Vinall   M  66
# 32       Rose Hall beach              Paddling    Rachel Smith   F  26
#
#                                                Injury Fatal Y/N  \
# 0                                  Severe hand injury         N
# 28                                         No injury          N
# 30  Multiple injuries to body one hand and leg bit...         Y
# 31                                    Injury to thigh         N
# 32             minor injuries to fingers of left hand         N
#
#                      Species
# 0                Nurse shark
# 28                Great White
# 30                 Not stated
# 31                 Not stated
# 32  Small shark 1m (3ft) long

# %%
df_50_last_years = df_50_last_years.dropna(subset=['Country']) # Removed rows with NaN in "Country"
df_50_last_years
# Out:
#                      Date    Year        Type       Country  \
# 0            14th October  2025.0  Unprovoked      Columbia
# 28               31st May  2025.0  Unprovoked           Usa
# 30    2025-05-26 00:00:00  2025.0  Unprovoked       Vanuatu
# 31    2025-05-15 00:00:00  2025.0  Unprovoked     Australia
# 32    2025-05-08 00:00:00  2025.0  Unprovoked       Jamaica
# ...                   ...     ...         ...           ...
# 3913          02-May-1976  1976.0  Watercraft  South Africa
# 3914          28-Apr-1976  1976.0     Invalid           Usa
# 3915          12-Mar-1976  1976.0  Unprovoked           Usa
# 3916          12-Mar-1976  1976.0  Watercraft  South Africa
# 3892          23-Nov-1976  1976.0     Invalid  South Africa
#
#                       State                          Location  \
# 0      Bolivar, del Isolate                 Catagena Province
# 28               California               Montara State Beach
# 30              South Santo              Espiitu Santo Island
# 31          South Australia                    Port Noarlunga
# 32              Montego Bay                   Rose Hall beach
# ...                     ...                               ...
# 3913  Western Cape Province              40 km off Cape Point
# 3914                  Texas                  Galveston Island
# 3915                Florida  New Smyrna Beach, Volusia County
# 3916  Western Cape Province                     Robberg Point
# 3892          KwaZulu-Natal                      Warner Beach
#
#                                       Activity  \
# 0                         Swimming with sharks
# 28                                     Surfing
# 30                                    Swimming
# 31                                    Swimming
# 32                                    Paddling
# ...                                        ...
# 3913  Competing in a light tackle game fishing
# 3914                                       NaN
# 3915                                  Standing
# 3916                                   Fishing
# 3892                                  Swimming
#
#                                                    Name  Sex       Age  \
# 0                                            Male child    M        14
# 28                                          Jens Heller    M        42
# 30                                                Tumas    M        14
# 31                                       Richard Vinall    M        66
# 32                                         Rachel Smith    F        26
# ...                                                 ...  ...       ...
# 3913  6 m skiboat, occupants: Terry McManus, Dan Cla...  NaN       NaN
# 3914                                            Unknown  NaN       NaN
# 3915                                        Glen Wright    M  21 or 26
# 3916               boat, occupants: Jacob Kruger & crew  NaN       NaN
# 3892                                      Jimmy Jackson    M        17
#
#                                                  Injury Fatal Y/N  \
# 0                                    Severe hand injury         N
# 28                                           No injury          N
# 30    Multiple injuries to body one hand and leg bit...         Y
# 31                                      Injury to thigh         N
# 32               minor injuries to fingers of left hand         N
# ...                                                 ...       ...
# 3913   Shark following hooked fish, rammed & holed boat         N
# 3914  Possible drowning victim, remains retrieved fr...       NaN
# 3915                            Lacerations to left leg         N
# 3916   No injury to occupants, shark buckled prop shaft         N
# 3892                                 Laceration to foot       NaN
#
#                                                Species
# 0                                          Nurse shark
# 28                                          Great White
# 30                                           Not stated
# 31                                           Not stated
# 32                            Small shark 1m (3ft) long
# ...                                                 ...
# 3913                        Mako shark, 180-kg [397-lb]
# 3914  Shark involvement prior to death was not confi...
# 3915                                                NaN
# 3916                                        Whale shark
# 3892                              Questionable incident
#
# [3930 rows x 13 columns]

# %% [markdown]
# ## Clean Sex

# %%
df_50_last_years['Sex'].unique()
# Out:
# array(['M', 'F', 'F ', 'M ', nan, ' M', 'm', 'lli'], dtype=object)

# %%
df_50_last_years['Sex'] = df_50_last_years['Sex'].str.strip().str.upper()
df_50_last_years['Sex'].unique()
# Out:
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/4248088207.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array(['M', 'F', nan, 'LLI'], dtype=object)

# %%
df_50_last_years[df_50_last_years['Sex'] == "LLI"] # there is only one row with LLI in a column Sex, so I will change it to NaN
# Out:
#              Date    Year        Type Country       State  \
# 2344  11-Nov-2004  2004.0  Unprovoked     Usa  California
#
#                                             Location Activity        Name  \
# 2344  Bunkers, Humboldt Bay, Eureka, Humboldt County  Surfing  Brian Kang
#
#       Sex Age                              Injury Fatal Y/N  \
# 2344  LLI  38  Lacerations to hand, knee & thigh          N
#
#                      Species
# 2344  5.5 m [18'] white shark

# %%
df_50_last_years['Sex'] = df_50_last_years['Sex'].replace('LLI', np.nan)
# Out:
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/1845379289.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_50_last_years[df_50_last_years['Sex'].isna()]
# Out:
#                       Date    Year          Type           Country  \
# 162   Reported 14 Jul-2023  2023.0    Watercraft      South Africa
# 146            23 Aug-2023  2023.0    Unprovoked               Usa
# 281            07-May-2022  2022.0    Unprovoked  French Polynesia
# 277            27-May-2022  2022.0    Unprovoked         Australia
# 253            19-Jul-2022  2022.0  Questionable               Usa
# ...                    ...     ...           ...               ...
# 3897           22-Sep-1976  1976.0  Sea Disaster     New Caledonia
# 3917           09-Mar-1976  1976.0    Watercraft      South Africa
# 3913           02-May-1976  1976.0    Watercraft      South Africa
# 3914           28-Apr-1976  1976.0       Invalid               Usa
# 3916           12-Mar-1976  1976.0    Watercraft      South Africa
#
#                       State                        Location  \
# 162   Eastern Cape Province                    Chinta East
# 146          North Carolina    Oak Island, Brunswick County
# 281               Bora Bora                         To'opua
# 277       Western Australia                       Yallingup
# 253                 Florida  Cape Canaveral, Brevard County
# ...                     ...                             ...
# 3897                    NaN                        Sarcelle
# 3917  Western Cape Province   2 km from Macassar, False Bay
# 3913  Western Cape Province            40 km off Cape Point
# 3914                  Texas                Galveston Island
# 3916  Western Cape Province                   Robberg Point
#
#                                       Activity  \
# 162                   Watching the sardine run
# 146                                     Wading
# 281                                        NaN
# 277                                    Surfing
# 253                                        NaN
# ...                                        ...
# 3897                                 Shipwreck
# 3917                                       NaN
# 3913  Competing in a light tackle game fishing
# 3914                                       NaN
# 3916                                   Fishing
#
#                                                    Name  Sex  Age  \
# 162                                                crew  NaN  NaN
# 146                                               child  NaN    9
# 281                                                 NaN  NaN  NaN
# 277                                                 NaN  NaN  NaN
# 253                                                 NaN  NaN  NaN
# ...                                                 ...  ...  ...
# 3897                                       a small boat  NaN  NaN
# 3917                             5 m skiboat; Stephanie  NaN  NaN
# 3913  6 m skiboat, occupants: Terry McManus, Dan Cla...  NaN  NaN
# 3914                                            Unknown  NaN  NaN
# 3916               boat, occupants: Jacob Kruger & crew  NaN  NaN
#
#                                                  Injury Fatal Y/N  \
# 162          No injury to occupants, shark defated boat         N
# 146                            Minor injury to shoulder         N
# 281                                         Hand bitten         N
# 277          Knocked off board by a  shark.   No injury         N
# 253                                      minor injuries         N
# ...                                                 ...       ...
# 3897  It was believed that survivors were killed by ...         N
# 3917                        Shark breached hull of boat         N
# 3913   Shark following hooked fish, rammed & holed boat         N
# 3914  Possible drowning victim, remains retrieved fr...       NaN
# 3916   No injury to occupants, shark buckled prop shaft         N
#
#                                                Species
# 162                                                 NaN
# 146                                                 NaN
# 281                                                 NaN
# 277                             Bronze whaler shark, 2m
# 253                     Shark involvement not confirmed
# ...                                                 ...
# 3897                                                NaN
# 3917                         White shark named “Spotty”
# 3913                        Mako shark, 180-kg [397-lb]
# 3914  Shark involvement prior to death was not confi...
# 3916                                        Whale shark
#
# [229 rows x 13 columns]

# %% [markdown]
# ## Clean Fatal

# %%
df_50_last_years['Fatal Y/N'].unique()
# Out:
# array(['N', 'Y', 'F', nan, 'M', 'n', 'Nq', 'UNKNOWN', 2017], dtype=object)

# %%
df_50_last_years['Fatal Y/N'] = df_50_last_years['Fatal Y/N'].str.strip().str.upper()
df_50_last_years['Fatal Y/N'].unique()
# Out:
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/1294677114.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array(['N', 'Y', 'F', nan, 'M', 'NQ', 'UNKNOWN'], dtype=object)

# %%
df_50_last_years['Fatal Y/N'].value_counts(dropna=False)
# Out:
# Fatal Y/N
# N          3202
# Y           430
# NaN         265
# UNKNOWN      24
# F             5
# M             3
# NQ            1
# Name: count, dtype: int64

# %%
df_50_last_years['Fatal Y/N'] = df_50_last_years['Fatal Y/N'].replace({'UNKNOWN': np.nan,'NQ': np.nan,'M': np.nan,'F': 'Y'})
# Out:
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/702274590.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_50_last_years['Fatal Y/N'].value_counts(dropna=False)
# Out:
# Fatal Y/N
# N      3202
# Y       435
# NaN     293
# Name: count, dtype: int64

# %% [markdown]
# ## Clean Age

# %%
df_50_last_years['Age'].unique() # we need to keep the age range for potential clients 18 - 60
# Out:
# array(['14', '42', '66', '26', '45', '20', '30', '?', '30+', '37', '56',
#        '29', 35, 58, 29, 24, 20, 55, 17, 12, 37, 36, 23, 40, 28, '40+',
#        '9', '7', '12', '54', '48', '57', '8', '63', '39', '19', '50+',
#        '85', '40', '16', '21', '18', '69', 16, 15, 45, 46, 19, 27, 25, 65,
#        64, '46', 26, '13', nan, '11', '32', '10', '64', '62', 49, 21, 57,
#        38, 69, 48, '60+', 61, 'Middle age', 68, 43, 14, 41, 30, 33, '15',
#        '35', '24', '22', '50s', '47', '25', '73', '!2', '53', '34', '49',
#        '41', '60', '59', '6', '30s', '17', '67', '58', '50', '55', '44',
#        '52', '77', '20s', '65', '20/30', '38', 32, 8, 22, 56, 'Teen', 62,
#        'teen', 18, '40s', 42, 13, 'M', 50, 51, 39, '31', '51', '43', '68',
#        60, 10, 53, 54, 59, 71, 7, 52, 73, '45 and 15', 75, 9, '!!', 31,
#        '!6', 34, 11, 47, 63, 4, 70, 67, "20's", '9 & 60', 74, '28 & 22',
#        44, '22, 57, 31', '60s', 6, 'a minor', 82, 3, '40?', 66, 72, '36',
#        '23', '71', '70', '18 months', '61', '28', '33', '28 & 26', '74',
#        '27', '3', '86', '5', '18 or 20', '46 & 34', '28, 23 & 30',
#        '12 or 13', 'Teens', 77, 84, '36 & 26', '8 or 10', '30 or 36', ' ',
#        '\xa0 ', 'mid-30s', '33 or 37', '6½', '21 & ?', 5, '23 & 20',
#        ' 30', '20?', '7      &    31', ' 28', '32 & 30', "60's",
#        '16 to 18', '87', 'Elderly', 'mid-20s', 'Ca. 33', '74 ', '45 ',
#        '21 or 26'], dtype=object)

# %%
df_50_last_years['Age'].value_counts()
# Out:
# Age
# 15           63
# 17           53
# 20           53
# 17           52
# 21           51
#              ..
# 72            1
# 18 months     1
# 28 & 26       1
# 74            1
# 21 or 26      1
# Name: count, Length: 205, dtype: int64

# %%
df_50_last_years['Age'].astype(str).str.strip()
# Out:
# 0             14
# 28            42
# 30            14
# 31            66
# 32            26
#           ...
# 3913         nan
# 3914         nan
# 3915    21 or 26
# 3916         nan
# 3892          17
# Name: Age, Length: 3930, dtype: object

# %%
df_50_last_years['Age'].unique()
# Out:
# array(['14', '42', '66', '26', '45', '20', '30', '?', '30+', '37', '56',
#        '29', 35, 58, 29, 24, 20, 55, 17, 12, 37, 36, 23, 40, 28, '40+',
#        '9', '7', '12', '54', '48', '57', '8', '63', '39', '19', '50+',
#        '85', '40', '16', '21', '18', '69', 16, 15, 45, 46, 19, 27, 25, 65,
#        64, '46', 26, '13', nan, '11', '32', '10', '64', '62', 49, 21, 57,
#        38, 69, 48, '60+', 61, 'Middle age', 68, 43, 14, 41, 30, 33, '15',
#        '35', '24', '22', '50s', '47', '25', '73', '!2', '53', '34', '49',
#        '41', '60', '59', '6', '30s', '17', '67', '58', '50', '55', '44',
#        '52', '77', '20s', '65', '20/30', '38', 32, 8, 22, 56, 'Teen', 62,
#        'teen', 18, '40s', 42, 13, 'M', 50, 51, 39, '31', '51', '43', '68',
#        60, 10, 53, 54, 59, 71, 7, 52, 73, '45 and 15', 75, 9, '!!', 31,
#        '!6', 34, 11, 47, 63, 4, 70, 67, "20's", '9 & 60', 74, '28 & 22',
#        44, '22, 57, 31', '60s', 6, 'a minor', 82, 3, '40?', 66, 72, '36',
#        '23', '71', '70', '18 months', '61', '28', '33', '28 & 26', '74',
#        '27', '3', '86', '5', '18 or 20', '46 & 34', '28, 23 & 30',
#        '12 or 13', 'Teens', 77, 84, '36 & 26', '8 or 10', '30 or 36', ' ',
#        '\xa0 ', 'mid-30s', '33 or 37', '6½', '21 & ?', 5, '23 & 20',
#        ' 30', '20?', '7      &    31', ' 28', '32 & 30', "60's",
#        '16 to 18', '87', 'Elderly', 'mid-20s', 'Ca. 33', '74 ', '45 ',
#        '21 or 26'], dtype=object)

# %%
df_50_last_years['Age']
# Out:
# 0             14
# 28            42
# 30            14
# 31            66
# 32            26
#           ...
# 3913         NaN
# 3914         NaN
# 3915    21 or 26
# 3916         NaN
# 3892          17
# Name: Age, Length: 3930, dtype: object

# %%
df_50_last_years.nunique() # How to approach cleaning/using data in Injury, Age, Activity, Date(for season)
# Out:
# Date         3339
# Year           50
# Type           12
# Country       126
# State         487
# Location     2673
# Activity      623
# Name         3280
# Sex             2
# Age           205
# Injury       2414
# Fatal Y/N       2
# Species      1187
# dtype: int64

# %%
df_50_last_years.head()
# Out:
#                    Date    Year        Type    Country                  State  \
# 0          14th October  2025.0  Unprovoked   Columbia   Bolivar, del Isolate
# 28             31st May  2025.0  Unprovoked        Usa             California
# 30  2025-05-26 00:00:00  2025.0  Unprovoked    Vanuatu            South Santo
# 31  2025-05-15 00:00:00  2025.0  Unprovoked  Australia        South Australia
# 32  2025-05-08 00:00:00  2025.0  Unprovoked    Jamaica            Montego Bay
#
#                 Location              Activity            Name Sex Age  \
# 0      Catagena Province  Swimming with sharks      Male child   M  14
# 28   Montara State Beach               Surfing     Jens Heller   M  42
# 30  Espiitu Santo Island              Swimming           Tumas   M  14
# 31        Port Noarlunga              Swimming  Richard Vinall   M  66
# 32       Rose Hall beach              Paddling    Rachel Smith   F  26
#
#                                                Injury Fatal Y/N  \
# 0                                  Severe hand injury         N
# 28                                         No injury          N
# 30  Multiple injuries to body one hand and leg bit...         Y
# 31                                    Injury to thigh         N
# 32             minor injuries to fingers of left hand         N
#
#                      Species
# 0                Nurse shark
# 28                Great White
# 30                 Not stated
# 31                 Not stated
# 32  Small shark 1m (3ft) long

# %% [markdown]
# ## Convert months into seasons

# %%
df_50_last_years['Date_raw'] = df_50_last_years['Date'] # keeping original Date column for potential season extraction
# Out:
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/2126515903.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.columns = df.columns.str.strip()
if "Date" not in df.columns:
    raise KeyError(f"'Date' column not found. Columns: {list(df.columns)}") # ensure 'Date' column exists

df["Date_raw"] = df["Date"].astype(str) # keep the raw for QA

# %%
s = df["Date"].astype(str).str.strip()
s = s.str.replace(r"(?<=\d)(st|nd|rd|th)", "", regex=True)
s = s.str.replace(r"\b\d{3,4}\s*hrs\b", "", regex=True, )
s = s.replace([r"^\s*(not\s*stated|unknown|undetermined|\?|nan)\s*$", ""],
              np.nan, regex=True) # normalize placeholders to NaN

# %%
parsed = pd.to_datetime(s, errors="coerce", dayfirst=True) # initial parse attempt
# Out:
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/1353127596.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
mname = s.str.extract(r"(?i)\b(jan|feb|mar|apr|may|jun|jul|aug|sep|sept|oct|nov|dec)\b", expand=False)
month_map = {"jan":1,"feb":2,"mar":3,"apr":4,"may":5,"jun":6,
             "jul":7,"aug":8,"sep":9,"sept":9,"oct":10,"nov":11,"dec":12}
mnum = mname.str.lower().map(month_map)

year_series = pd.to_numeric(df.get("Year", np.nan), errors="coerce")
mask = parsed.isna() & mnum.notna() & year_series.notna()
parsed.loc[mask] = pd.to_datetime(
    dict(year=year_series[mask].astype(int), month=mnum[mask].astype(int), day=1),
    errors="coerce"
) # construct dates where month name and year exist

# %%
df["Date_parsed"] = parsed  
print("Date_parsed dtype:", df["Date_parsed"].dtype) # ensure datetime64[ns]
# Out:
# Date_parsed dtype: datetime64[ns]

# %%
def month_to_season(m):
    if pd.isna(m): return None
    if m in [12,1,2]:  return "Winter"
    if m in [3,4,5]:   return "Spring"
    if m in [6,7,8]:   return "Summer"
    return "Autumn"

df["Season"] = df["Date_parsed"].dt.month.map(month_to_season)

df.loc[df["Season"].isna() & mnum.notna(), "Season"] = mnum.map(month_to_season)

df["Season"] = pd.Categorical(df["Season"],
                              categories=["Winter","Spring","Summer","Autumn"],
                              ordered=True) # ordered category (nice for sorting/plots)

# %%
print("\nSeason counts (incl. missing):")
print(df["Season"].value_counts(dropna=False))
display(df[["Date_raw","Date_parsed","Season"]].head(12)) # show sample results
# Out:
# Season counts (incl. missing):
# Season
# Summer    2006
# Winter    1783
# Autumn    1569
# Spring    1421
# NaN        271
# Name: count, dtype: int64
#           Date_raw Date_parsed Season
# 0     14th October         NaT    NaN
# 1     11th October         NaT    NaN
# 2      7th October         NaT    NaN
# 3   29th September         NaT    NaN
# 4   27th September         NaT    NaN
# 5    6th September         NaT    NaN
# 6    1st September         NaT    NaN
# 7      30th August         NaT    NaN
# 8      18th August         NaT    NaN
# 9      17th August         NaT    NaN
# 10     16th August         NaT    NaN
# 11      7th August         NaT    NaN

# %%
df_50_last_years = df.copy()
assert "Season" in df_50_last_years.columns

# %%
df_50_last_years["Date"].unique
# Out:
# <bound method Series.unique of 0         14th October
# 1         11th October
# 2          7th October
# 3       29th September
# 4       27th September
#              ...
# 7045       Before 1903
# 7046       Before 1903
# 7047         1900-1905
# 7048         1883-1889
# 7049         1845-1853
# Name: Date, Length: 7050, dtype: object>

# %%
df_50_last_years.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         7050 non-null   object
#  1   Year         7050 non-null   float64
#  2   Type         7032 non-null   object
#  3   Country      7000 non-null   object
#  4   State        6564 non-null   object
#  5   Location     6483 non-null   object
#  6   Activity     6465 non-null   object
#  7   Name         6831 non-null   object
#  8   Sex          6471 non-null   object
#  9   Age          4056 non-null   object
#  10  Injury       7015 non-null   object
#  11  Fatal Y/N    6489 non-null   object
#  12  Time         3524 non-null   object
#  13  Species      3919 non-null   object
#  14  Temp_year    7002 non-null   float64
#  15  Date_raw     7050 non-null   object
#  16  Date_parsed  6762 non-null   datetime64[ns]
#  17  Season       6779 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(2), object(14)
# memory usage: 943.5+ KB

# %% [markdown]
# ## Injury severity

# %%
# Function to classify injury severity
def classify_injury(text):
    if pd.isna(text):
        return np.nan

    text = text.lower()

    # Severe injuries
    severe_keywords = [
        "fatal", "death", "amputation", "severed", "torn off",
        "massive", "critical", "major", "severe", "life-threatening",
        "lost", "missing limb", "unconscious"
    ]

    # Medium injuries
    medium_keywords = [
        "deep", "laceration", "multiple bites", "serious", "fracture",
        "severe bleeding", "puncture", "bitten", "torn", "damaged"
    ]

    # Low injuries
    low_keywords = [
        "minor", "small", "superficial", "scratch", "abrasion",
        "bruise", "nipped", "no injury", "slight"
    ]

    if any(word in text for word in severe_keywords):
        return "Severe"
    elif any(word in text for word in medium_keywords):
        return "Medium"
    elif any(word in text for word in low_keywords):
        return "Low"
    else:
        return "Unknown"

# %%
df_50_last_years['Injury_Severity'] = df_50_last_years['Injury'].apply(classify_injury) # classify injury severity

# %%
# Display injury severity counts and sample data
print(df_50_last_years['Injury_Severity'].value_counts(dropna=False))
display(df_50_last_years[['Date', 'Activity', 'Injury', 'Injury_Severity']].head(10))
# Out:
# Injury_Severity
# Medium     2619
# Severe     1931
# Unknown    1446
# Low        1019
# NaN          35
# Name: count, dtype: int64
#              Date               Activity  \
# 0    14th October   Swimming with sharks
# 1    11th October       Fishing/swimming
# 2     7th October                Surfing
# 3  29th September               Swimming
# 4  27th September  Diving-Tagging sharks
# 5   6th September                Surfing
# 6   1st September             Snorkeling
# 7     30th August               Swimming
# 8     18th August                Surfing
# 9     17th August           Spearfishing
#
#                                  Injury Injury_Severity
# 0                    Severe hand injury          Severe
# 1           Serious abdonminal injuries          Medium
# 2                  Lacerations to calf           Medium
# 3                   Leg and foot injury         Unknown
# 4                    Head face and arms         Unknown
# 5             Both legs and arm severed          Severe
# 6                           Bite to leg         Unknown
# 7                           Bite to leg         Unknown
# 8  None sustained board severly damaged          Medium
# 9             Severe injuries no detail          Severe

# %%
severity_order = ["Low", "Medium", "Severe", "Unknown"]
df_50_last_years["Injury_Severity"] = (
    df_50_last_years["Injury_Severity"]
    .fillna("Unknown")
    .replace({"minor":"Low","serious":"Medium","major":"Severe"})  # normalize some common terms
    .astype("category")
    .cat.set_categories(severity_order, ordered=True)
)

# %%
def severity_bar(df, x, top_n=None, title="", show=True):
    data = df.copy()

    # Clean severity and x
    data["Injury_Severity"] = (
        data["Injury_Severity"]
        .fillna("Unknown")
        .astype(str).str.strip().str.title()
    )
    data["Injury_Severity"] = pd.Categorical(
        data["Injury_Severity"],
        categories=severity_order,
        ordered=True
    )

    # Clean the grouping column
    data[x] = data[x].astype(str).str.strip()
    data = data.replace({"nan": np.nan})  # convert "nan" strings to NaN
    data = data.dropna(subset=[x, "Injury_Severity"])

    # Filter to top N categories by total incidents
    if top_n:
        top_vals = data[x].value_counts(dropna=False).nlargest(top_n).index
        data = data[data[x].isin(top_vals)]

    # Aggregate; observed=True avoids injecting unused categories
    g = (
        data.groupby([x, "Injury_Severity"], observed=True)
        .size()
        .reset_index(name="Attack_Count")
    )

    # Order x by total for nicer sorting
    totals = g.groupby(x)["Attack_Count"].sum().sort_values(ascending=False)
    g[x] = pd.Categorical(g[x], categories=list(totals.index), ordered=True)

    fig = px.bar(
        g.sort_values([x, "Injury_Severity"]),
        x=x, y="Attack_Count",
        color="Injury_Severity",
        category_orders={"Injury_Severity": severity_order},
        barmode="stack",
        title=title,
    )
    fig.update_layout(legend_title="Severity", xaxis_title=x, yaxis_title="Number of Attacks")

    if show:
        fig.show()
    return fig

# %%
_ = severity_bar(
    df_50_last_years, "Country", top_n=10,
    title="Shark Attack Severity by Country (Last 50 Years)"
)

# %% [markdown]
# ## Moon phases & attacks

# %%
moon_df = pd.read_excel ("moon_phases_last_50_years.xls")
moon_df.head()
# Out:
#                      Date      Moon_Phase
# 0 1975-11-23 14:29:28.397  Waning Gibbous
# 1 1975-11-24 14:29:28.397    Last Quarter
# 2 1975-11-25 14:29:28.397    Last Quarter
# 3 1975-11-26 14:29:28.397    Last Quarter
# 4 1975-11-27 14:29:28.397    Last Quarter

# %%
df_50_last_years["Date"] = pd.to_datetime(df_50_last_years["Date"], errors="coerce")
moon_df["Date"]          = pd.to_datetime(moon_df["Date"],          errors="coerce")

df_50_last_years["Date_key"] = df_50_last_years["Date"].dt.date
moon_df["Date_key"]          = moon_df["Date"].dt.date
# Out:
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/2626927814.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
merged_df = pd.merge(
    df_50_last_years,
    moon_df[["Date_key", "Moon_Phase"]],
    on="Date_key",
    how="left"
)

# %%
print("Rows in merged_df:", len(merged_df))
print("Season null %:", merged_df["Season"].isna().mean())
print("Moon_Phase null %:", merged_df["Moon_Phase"].isna().mean())
print(merged_df[["Date","Date_key","Season","Moon_Phase"]].head())
# Out:
# Rows in merged_df: 7050
# Season null %: 0.03843971631205674
# Moon_Phase null %: 0.4736170212765957
#   Date Date_key Season Moon_Phase
# 0  NaT      NaT    NaN        NaN
# 1  NaT      NaT    NaN        NaN
# 2  NaT      NaT    NaN        NaN
# 3  NaT      NaT    NaN        NaN
# 4  NaT      NaT    NaN        NaN

# %%
season_moon_counts_dbg = (
    merged_df.groupby(["Season", "Moon_Phase"], dropna=False)
    .size()
    .reset_index(name="Attack_Count")
)
print(season_moon_counts_dbg.head(12))

valid_phases = [
    "New Moon","Waxing Crescent","First Quarter","Waxing Gibbous",
    "Full Moon","Waning Gibbous","Last Quarter","Waning Crescent"
]
season_moon_counts = season_moon_counts_dbg[
    season_moon_counts_dbg["Moon_Phase"].isin(valid_phases)
].copy()
# Out:
#     Season       Moon_Phase  Attack_Count
# 0   Winter    First Quarter            85
# 1   Winter        Full Moon            94
# 2   Winter     Last Quarter            83
# 3   Winter         New Moon           113
# 4   Winter  Waning Crescent           112
# 5   Winter   Waning Gibbous            91
# 6   Winter  Waxing Crescent            84
# 7   Winter   Waxing Gibbous           106
# 8   Winter              NaN          1015
# 9   Spring    First Quarter           106
# 10  Spring        Full Moon            97
# 11  Spring     Last Quarter           100
# /var/folders/pl/qjnl2n816kd5trwzkx1r4f9r0000gp/T/ipykernel_8889/3910147789.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
season_moon_counts["Moon_Phase"] = pd.Categorical(
    season_moon_counts["Moon_Phase"], categories=valid_phases, ordered=True
)
season_order = ["Winter","Spring","Summer","Autumn"]
if "Season" in season_moon_counts:
    season_moon_counts["Season"] = pd.Categorical(
        season_moon_counts["Season"], categories=season_order, ordered=True
    )

print(season_moon_counts.head())
# Out:
#    Season       Moon_Phase  Attack_Count
# 0  Winter    First Quarter            85
# 1  Winter        Full Moon            94
# 2  Winter     Last Quarter            83
# 3  Winter         New Moon           113
# 4  Winter  Waning Crescent           112

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.13/site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from plotly) (24.2)

# %%
import plotly.express as px

# %%
fig = px.bar(
    season_moon_counts.sort_values(["Moon_Phase","Season"]),
    x="Moon_Phase", y="Attack_Count", color="Season",
    barmode="group",
    title="Shark Attacks by Moon Phase and Season (Last 50 Years)",
    labels={"Attack_Count":"Number of Attacks","Moon_Phase":"Moon Phase"}
)
fig.show()
